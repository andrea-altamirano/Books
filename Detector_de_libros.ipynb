# %% [markdown]
# <a href="https://colab.research.google.com/github/andrea-altamirano/Books/blob/main/Detector_de_libros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/andrea-altamirano/Books.git
# Out:
# fatal: destination path 'Books' already exists and is not an empty directory.

# %%
# !pip install roboflow ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="xYMbMyk898HPr26tQ1p2")
project = rf.workspace("andreas-workspace-iaa5q").project("books-qqqmx-qwjpm")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
from ultralytics import YOLO
model = YOLO("yolo11s.pt")

# %%
data_path = "/content/Books-1/data.yaml"
results = model.train(data=data_path,
                      epochs=10,
                      imgsz=640)
# Out:
# Ultralytics 8.4.83 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
custom_model = YOLO("/content/runs/detect/train/weights/best.pt")

res = custom_model("/content/Books-1/test/images")
# Out:
# image 1/357 /content/Books-1/test/images/001-hands-holding-hard-cover-book-catalog-dust-jacket-editorial-graphic-design-psd-resource-mockup-pixeden_jpg.rf.fef5153f8ca6d6cefb162471011c9318.jpg: 640x640 1 book, 15.6ms
# image 2/357 /content/Books-1/test/images/001-holding-hand-paperback-book-editorial-cover-graphic-psd-mockup-pixeden_jpg.rf.2ad5136b35a3b7bbbb83ed6121f8e83d.jpg: 640x640 1 book, 15.6ms
# image 3/357 /content/Books-1/test/images/001037163b0f89d9_jpg.rf.e4621afe0c332990b08f13071e2b86b3.jpg: 640x640 1 book, 15.5ms
# image 4/357 /content/Books-1/test/images/0010618063851449_jpg.rf.3cbb13c20ec15a341ecebc4ef20058ca.jpg: 640x640 1 book, 15.4ms
# image 5/357 /content/Books-1/test/images/0049f1eeeae7e0de_jpg.rf.5c44233432ee438a03123834b5db8668.jpg: 640x640 1 book, 15.5ms
# image 6/357 /content/Books-1/test/images/006027ad924c0d01_jpg.rf.26854916da112e6c1627d2cf8fa4309b.jpg: 640x640 1 book, 15.5ms
# ...

# %%
res[45].show()
# Out:
# <PIL.Image.Image image mode=RGB size=640x640>

# %%
# Código Extra Para Visual :


#from ultralytics import YOLO
#import cv2

#model = YOLO("best.pt")

#cap = cv2.VideoCapture(0)

#while cap.isOpened():
    #ret, frame = cap.read()
    #if not ret:
        #break
    #results = model(frame)

    #annotated_frame = results[0].plot()

    #cv2.imshow("YOLO Inference", annotated_frame)

    #if cv2.waitKey(1) & 0xFF == 27:
        #break

#cap.release()
#cv2.destroyAllWindows()
